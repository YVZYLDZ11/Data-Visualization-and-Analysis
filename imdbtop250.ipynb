# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("imdbTop250.csv", parse_dates= ["Date"])
data.head()
# Out:
#    Ranking  IMDByear           IMDBlink                     Title       Date  \
# 0        1      1996  /title/tt0076759/                 Star Wars 1977-01-01
# 1        2      1996  /title/tt0111161/  The Shawshank Redemption 1994-01-01
# 2        3      1996  /title/tt0117951/             Trainspotting 1996-01-01
# 3        4      1996  /title/tt0114814/        The Usual Suspects 1995-01-01
# 4        5      1996  /title/tt0108598/        The Wrong Trousers 1993-01-01
#
#    RunTime                       Genre  Rating  Score    Votes   Gross  \
# 0      121  Action, Adventure, Fantasy     8.6   90.0  1254781  322.74
# 1      142                       Drama     9.3   80.0  2407245   28.34
# 2       93                       Drama     8.1   83.0   645186   16.50
# 3      106    Crime, Mystery, Thriller     8.5   77.0  1010775   23.34
# 4       30    Animation, Short, Comedy     8.3    NaN    51747     NaN
#
#          Director           Cast1             Cast2               Cast3  \
# ...

# %%
data.dtypes
# Out:
# Ranking       int64
# IMDByear      int64
# IMDBlink     object
# Title        object
# Date          int64
# RunTime       int64
# Genre        object
# Rating      float64
# Score       float64
# Votes         int64
# Gross       float64
# Director     object
# Cast1        object
# Cast2        object
# Cast3        object
# Cast4        object
# dtype: object

# %%
data.shape
# Out:
# (6250, 16)

# %%
data.describe()
# Out:
#           Ranking    IMDByear         Date      RunTime       Rating  \
# count  6250.00000  6250.00000  6250.000000  6250.000000  6250.000000
# mean    125.50000  2008.00000  1978.313120   125.507200     8.167728
# std      72.17398     7.21168    23.509933    30.899116     0.329375
# min       1.00000  1996.00000  1920.000000    16.000000     5.500000
# 25%      63.00000  2002.00000  1959.000000   105.000000     8.000000
# 50%     125.50000  2008.00000  1983.000000   121.000000     8.100000
# 75%     188.00000  2014.00000  1998.000000   138.000000     8.300000
# max     250.00000  2020.00000  2020.000000   321.000000     9.300000
#
#              Score         Votes        Gross
# count  5399.000000  6.250000e+03  5465.000000
# mean     84.304316  4.615469e+05    70.185208
# std      10.060331  4.533022e+05   101.989895
# min      61.000000  8.906000e+03     0.010000
# 25%      77.000000  1.141480e+05     5.380000
# 50%      85.000000  2.881270e+05    26.240000
# ...

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_23',
#  '_24',
#  '_25',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'd',
#  'da',
#  'data',
#  'exit',
#  'get_ipython',
#  'pd',
#  'plt',
#  'quit',
#  'sns']

# %%
data.isna().sum()
# Out:
# Ranking       0
# IMDByear      0
# IMDBlink      0
# Title         0
# Date          0
# RunTime       0
# Genre         0
# Rating        0
# Score       851
# Votes         0
# Gross       785
# Director      0
# Cast1         0
# Cast2         0
# Cast3         8
# Cast4         8
# dtype: int64

# %%
data.isna().sum()/data.shape[0]*100
# Out:
# Ranking      0.000
# IMDByear     0.000
# IMDBlink     0.000
# Title        0.000
# Date         0.000
# RunTime      0.000
# Genre        0.000
# Rating       0.000
# Score       13.616
# Votes        0.000
# Gross       12.560
# Director     0.000
# Cast1        0.000
# Cast2        0.000
# Cast3        0.128
# Cast4        0.128
# dtype: float64

# %%
data.notna()
# Out:
#       Ranking  IMDByear  IMDBlink  Title  Date  RunTime  Genre  Rating  Score  \
# 0        True      True      True   True  True     True   True    True   True
# 1        True      True      True   True  True     True   True    True   True
# 2        True      True      True   True  True     True   True    True   True
# 3        True      True      True   True  True     True   True    True   True
# 4        True      True      True   True  True     True   True    True  False
# ...       ...       ...       ...    ...   ...      ...    ...     ...    ...
# 6245     True      True      True   True  True     True   True    True   True
# 6246     True      True      True   True  True     True   True    True   True
# 6247     True      True      True   True  True     True   True    True   True
# 6248     True      True      True   True  True     True   True    True   True
# 6249     True      True      True   True  True     True   True    True   True
#
# ...

# %%
d = data.dropna()

# %%
d.shape
# Out:
# (4893, 16)

# %%
data.head()
# Out:
#    Ranking  IMDByear           IMDBlink                     Title  Date  \
# 0        1      1996  /title/tt0076759/                 Star Wars  1977
# 1        2      1996  /title/tt0111161/  The Shawshank Redemption  1994
# 2        3      1996  /title/tt0117951/             Trainspotting  1996
# 3        4      1996  /title/tt0114814/        The Usual Suspects  1995
# 4        5      1996  /title/tt0108598/        The Wrong Trousers  1993
#
#    RunTime                       Genre  Rating  Score    Votes   Gross  \
# 0      121  Action, Adventure, Fantasy     8.6   90.0  1254781  322.74
# 1      142                       Drama     9.3   80.0  2407245   28.34
# 2       93                       Drama     8.1   83.0   645186   16.50
# 3      106    Crime, Mystery, Thriller     8.5   77.0  1010775   23.34
# 4       30    Animation, Short, Comedy     8.3    NaN    51747     NaN
#
#          Director           Cast1             Cast2               Cast3  \
# ...

# %%
data.tail(8)
# Out:
#       Ranking  IMDByear           IMDBlink                   Title  Date  \
# 6242      243      2020  /title/tt0025316/   It Happened One Night  1934
# 6243      244      2020  /title/tt4857264/            Contratiempo  2016
# 6244      245      2020  /title/tt4430212/                Drishyam  2015
# 6245      246      2020  /title/tt1454029/                The Help  2011
# 6246      247      2020  /title/tt0093779/      The Princess Bride  1987
# 6247      248      2020  /title/tt0058946/  La battaglia di Algeri  1966
# 6248      249      2020  /title/tt2991224/             Mandariinid  2013
# 6249      250      2020  /title/tt2758880/              Kis Uykusu  2014
#
#       RunTime                       Genre  Rating  Score   Votes   Gross  \
# 6242      105             Comedy, Romance     8.1   87.0   96340    4.36
# 6243      106       Crime, Drama, Mystery     8.1    NaN  154253     NaN
# 6244      163       Crime, Drama, Mystery     8.2    NaN   74329    0.74
# ...

# %%
data.head(12)
# Out:
#     Ranking  IMDByear           IMDBlink                     Title  Date  \
# 0         1      1996  /title/tt0076759/                 Star Wars  1977
# 1         2      1996  /title/tt0111161/  The Shawshank Redemption  1994
# 2         3      1996  /title/tt0117951/             Trainspotting  1996
# 3         4      1996  /title/tt0114814/        The Usual Suspects  1995
# 4         5      1996  /title/tt0108598/        The Wrong Trousers  1993
# 5         6      1996  /title/tt0112691/             A Close Shave  1995
# 6         7      1996  /title/tt0117731/  Star Trek: First Contact  1996
# 7         8      1996  /title/tt0034583/                Casablanca  1942
# 8         9      1996  /title/tt0083658/              Blade Runner  1982
# 9        10      1996  /title/tt0108052/          Schindler's List  1993
# 10       11      1996  /title/tt0033467/              Citizen Kane  1941
# 11       12      1996  /title/tt0110912/              Pulp Fiction  1994
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6250 entries, 0 to 6249
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ranking   6250 non-null   int64
#  1   IMDByear  6250 non-null   int64
#  2   IMDBlink  6250 non-null   object
#  3   Title     6250 non-null   object
#  4   Date      6250 non-null   int64
#  5   RunTime   6250 non-null   int64
#  6   Genre     6250 non-null   object
#  7   Rating    6250 non-null   float64
#  8   Score     5399 non-null   float64
#  9   Votes     6250 non-null   int64
#  10  Gross     5465 non-null   float64
#  11  Director  6250 non-null   object
#  12  Cast1     6250 non-null   object
#  13  Cast2     6250 non-null   object
#  14  Cast3     6242 non-null   object
#  15  Cast4     6242 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 781.4+ KB

# %%
da = data.loc[data["Rating"]>6]
da
# Out:
#       Ranking  IMDByear           IMDBlink                     Title  Date  \
# 0           1      1996  /title/tt0076759/                 Star Wars  1977
# 1           2      1996  /title/tt0111161/  The Shawshank Redemption  1994
# 2           3      1996  /title/tt0117951/             Trainspotting  1996
# 3           4      1996  /title/tt0114814/        The Usual Suspects  1995
# 4           5      1996  /title/tt0108598/        The Wrong Trousers  1993
# ...       ...       ...                ...                       ...   ...
# 6245      246      2020  /title/tt1454029/                  The Help  2011
# 6246      247      2020  /title/tt0093779/        The Princess Bride  1987
# 6247      248      2020  /title/tt0058946/    La battaglia di Algeri  1966
# 6248      249      2020  /title/tt2991224/               Mandariinid  2013
# 6249      250      2020  /title/tt2758880/                Kis Uykusu  2014
#
# ...

# %%
da["Genre"].value_counts()
# Out:
# Drama                        496
# Crime, Drama                 294
# Crime, Drama, Thriller       210
# Biography, Drama, History    206
# Drama, War                   173
#                             ...
# Comedy, Crime, Romance         1
# Drama, Horror, Musical         1
# Horror, Thriller               1
# Comedy, Western                1
# Action, Crime, Sci-Fi          1
# Name: Genre, Length: 197, dtype: int64

# %%
da[(da["Genre"]== "Crime") | (da["Genre"]== "Drama")]
# Out:
#       Ranking  IMDByear           IMDBlink                            Title  \
# 1           2      1996  /title/tt0111161/         The Shawshank Redemption
# 2           3      1996  /title/tt0117951/                    Trainspotting
# 19         20      1996  /title/tt0073486/  One Flew Over the Cuckoo's Nest
# 152       153      1996  /title/tt0056801/                               8½
# 174       175      1996  /title/tt0042192/                    All About Eve
# ...       ...       ...                ...                              ...
# 6183      184      2020  /title/tt0046438/                 Tôkyô monogatari
# 6209      210      2020  /title/tt0074958/                          Network
# 6241      242      2020  /title/tt0087884/                     Paris, Texas
# 6245      246      2020  /title/tt1454029/                         The Help
# 6249      250      2020  /title/tt2758880/                       Kis Uykusu
#
# ...

# %%
da[(da["Genre"]== "Drama") & (da["Rating"]> 7)]
# Out:
#       Ranking  IMDByear           IMDBlink                            Title  \
# 1           2      1996  /title/tt0111161/         The Shawshank Redemption
# 2           3      1996  /title/tt0117951/                    Trainspotting
# 19         20      1996  /title/tt0073486/  One Flew Over the Cuckoo's Nest
# 152       153      1996  /title/tt0056801/                               8½
# 174       175      1996  /title/tt0042192/                    All About Eve
# ...       ...       ...                ...                              ...
# 6183      184      2020  /title/tt0046438/                 Tôkyô monogatari
# 6209      210      2020  /title/tt0074958/                          Network
# 6241      242      2020  /title/tt0087884/                     Paris, Texas
# 6245      246      2020  /title/tt1454029/                         The Help
# 6249      250      2020  /title/tt2758880/                       Kis Uykusu
#
# ...

# %%
da[(da["Genre"].isin(["Drama","Comedy","Horror"]))]
# Out:
#       Ranking  IMDByear           IMDBlink  \
# 1           2      1996  /title/tt0111161/
# 2           3      1996  /title/tt0117951/
# 12         13      1996  /title/tt0057012/
# 19         20      1996  /title/tt0073486/
# 35         36      1996  /title/tt0109445/
# ...       ...       ...                ...
# 6209      210      2020  /title/tt0074958/
# 6222      223      2020  /title/tt0079470/
# 6241      242      2020  /title/tt0087884/
# 6245      246      2020  /title/tt1454029/
# 6249      250      2020  /title/tt2758880/
#
#                                                   Title  Date  RunTime  \
# 1                              The Shawshank Redemption  1994      142
# 2                                         Trainspotting  1996       93
# 12    Dr. Strangelove or: How I Learned to Stop Worr...  1964       95
# 19                      One Flew Over the Cuckoo's Nest  1975      133
# 35                                               Clerks  1994       92
# ...

# %%
d = da[(da["Genre"].isin(["Drama","Comedy","Horror"]))]

# %%
d["Genre"].value_counts()
# Out:
# Drama     496
# Comedy     75
# Horror     16
# Name: Genre, dtype: int64

# %%
d
# Out:
#       Ranking  IMDByear           IMDBlink  \
# 1           2      1996  /title/tt0111161/
# 2           3      1996  /title/tt0117951/
# 12         13      1996  /title/tt0057012/
# 19         20      1996  /title/tt0073486/
# 35         36      1996  /title/tt0109445/
# ...       ...       ...                ...
# 6209      210      2020  /title/tt0074958/
# 6222      223      2020  /title/tt0079470/
# 6241      242      2020  /title/tt0087884/
# 6245      246      2020  /title/tt1454029/
# 6249      250      2020  /title/tt2758880/
#
#                                                   Title  Date  RunTime  \
# 1                              The Shawshank Redemption  1994      142
# 2                                         Trainspotting  1996       93
# 12    Dr. Strangelove or: How I Learned to Stop Worr...  1964       95
# 19                      One Flew Over the Cuckoo's Nest  1975      133
# 35                                               Clerks  1994       92
# ...

# %%
data["Rating"].mean()
# Out:
# 8.167727999999835

# %%
d["Rating"].mean()
# Out:
# 8.209540034071567

# %%
d.groupby(by= "Genre").mean()
# Out:
#            Ranking     IMDByear         Date     RunTime    Rating      Score  \
# Genre
# Comedy  120.240000  2005.320000  1975.093333   96.306667  8.112000  83.253333
# Drama   130.493952  2008.340726  1982.675403  127.250000  8.232056  81.059524
# Horror  196.437500  2005.562500  1972.375000  121.375000  7.968750  80.562500
#
#                 Votes       Gross
# Genre
# Comedy  337852.533333   24.189067
# Drama   529662.334677   34.800945
# Horror  347465.000000  218.516875

# %%
d.groupby(by= "Genre").agg(["min","mean","max"])
# Out:
#        Ranking                  IMDByear                     Date  \
#            min        mean  max      min         mean   max   min
# Genre
# Comedy       9  120.240000  239     1996  2005.320000  2020  1964
# Drama        1  130.493952  250     1996  2008.340726  2020  1948
# Horror     142  196.437500  249     1999  2005.562500  2013  1963
#
#                           RunTime  ... Rating Score                     Votes  \
#                mean   max     min  ...    max   min       mean    max     min
# Genre                              ...
# Comedy  1975.093333  1994      88  ...    8.4  61.0  83.253333   97.0  113752
# Drama   1982.675403  2018      89  ...    9.3  62.0  81.059524  100.0   18548
# Horror  1972.375000  1973     112  ...    8.0  74.0  80.562500   81.0   35555
#
#                                Gross
#                  mean      max   min        mean     max
# Genre
# Comedy  337852.533333   458817  0.20   24.189067   86.30
# ...

# %%
d.groupby(by= "Genre").agg(["min","mean","max"])
# Out:
#            Ranking     IMDByear         Date     RunTime    Rating      Score  \
# Genre
# Comedy  120.240000  2005.320000  1975.093333   96.306667  8.112000  83.253333
# Drama   130.493952  2008.340726  1982.675403  127.250000  8.232056  81.059524
# Horror  196.437500  2005.562500  1972.375000  121.375000  7.968750  80.562500
#
#                 Votes       Gross
# Genre
# Comedy  337852.533333   24.189067
# Drama   529662.334677   34.800945
# Horror  347465.000000  218.516875

# %%
d["Rating"].agg(["min","mean","max"])
# Out:
# min     7.10000
# mean    8.20954
# max     9.30000
# Name: Rating, dtype: float64

# %%
data.groupby("Genre")["Rating"].mean()
# Out:
# Genre
# Action, Adventure               8.290667
# Action, Adventure, Biography    7.900000
# Action, Adventure, Comedy       7.985294
# Action, Adventure, Drama        8.611504
# Action, Adventure, Fantasy      8.337500
#                                   ...
# Mystery, Romance, Thriller      8.300000
# Mystery, Sci-Fi, Thriller       8.000000
# Mystery, Thriller               8.313043
# Short, Fantasy, Horror          7.700000
# Western                         8.540909
# Name: Rating, Length: 197, dtype: float64

# %%
d.head()
# Out:
#     Ranking  IMDByear           IMDBlink  \
# 1         2      1996  /title/tt0111161/
# 2         3      1996  /title/tt0117951/
# 12       13      1996  /title/tt0057012/
# 19       20      1996  /title/tt0073486/
# 35       36      1996  /title/tt0109445/
#
#                                                 Title  Date  RunTime   Genre  \
# 1                            The Shawshank Redemption  1994      142   Drama
# 2                                       Trainspotting  1996       93   Drama
# 12  Dr. Strangelove or: How I Learned to Stop Worr...  1964       95  Comedy
# 19                    One Flew Over the Cuckoo's Nest  1975      133   Drama
# 35                                             Clerks  1994       92  Comedy
#
#     Rating  Score    Votes   Gross         Director              Cast1  \
# 1      9.3   80.0  2407245   28.34   Frank Darabont        Tim Robbins
# 2      8.1   83.0   645186   16.50      Danny Boyle      Ewan McGregor
# ...

# %%
drm_imdb= d[d["Genre"]== "Drama"]["Rating"]
cmdy_imdb= d[d["Genre"]== "Comedy"]["Rating"]
hrr_imdb= d[d["Genre"]== "Horror"]["Rating"]

# %%
sns.histplot(drm_imdb)
sns.histplot(cmdy_imdb)
sns.histplot(hrr_imdb)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
d.head()
# Out:
#     Ranking  IMDByear           IMDBlink  \
# 1         2      1996  /title/tt0111161/
# 2         3      1996  /title/tt0117951/
# 12       13      1996  /title/tt0057012/
# 19       20      1996  /title/tt0073486/
# 35       36      1996  /title/tt0109445/
#
#                                                 Title  Date  RunTime   Genre  \
# 1                            The Shawshank Redemption  1994      142   Drama
# 2                                       Trainspotting  1996       93   Drama
# 12  Dr. Strangelove or: How I Learned to Stop Worr...  1964       95  Comedy
# 19                    One Flew Over the Cuckoo's Nest  1975      133   Drama
# 35                                             Clerks  1994       92  Comedy
#
#     Rating  Score    Votes   Gross         Director              Cast1  \
# 1      9.3   80.0  2407245   28.34   Frank Darabont        Tim Robbins
# 2      8.1   83.0   645186   16.50      Danny Boyle      Ewan McGregor
# ...

# %%
d["Genre"].value_counts().index
# Out:
# Index(['Drama', 'Comedy', 'Horror'], dtype='object')

# %%
movies = d["Genre"].sort_values()
for movie in movies:
    sns.histplot(d[d["Genre"]== movie]["Rating"])

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15,10))
movies = d["Genre"].sort_values()

for movie in movies:
    sns.histplot(d[d["Genre"]== movie]["Rating"])

# %%
d.columns[6:8]
# Out:
# Index(['Genre', 'Rating'], dtype='object')

# %%
colons = d.columns[6:8]
movies = d["Genre"].unique()
#mplt.figure(figsize=(15,5))
for colon in colons:
    plt.figure(figsize=(15,10))
    for movie in movies:
                sns.displot(d[d["Genre"] == movie][colon])
plt.show()

# %%
d.head()
# Out:
#     Ranking  IMDByear           IMDBlink  \
# 1         2      1996  /title/tt0111161/
# 2         3      1996  /title/tt0117951/
# 12       13      1996  /title/tt0057012/
# 19       20      1996  /title/tt0073486/
# 35       36      1996  /title/tt0109445/
#
#                                                 Title  Date  RunTime   Genre  \
# 1                            The Shawshank Redemption  1994      142   Drama
# 2                                       Trainspotting  1996       93   Drama
# 12  Dr. Strangelove or: How I Learned to Stop Worr...  1964       95  Comedy
# 19                    One Flew Over the Cuckoo's Nest  1975      133   Drama
# 35                                             Clerks  1994       92  Comedy
#
#     Rating  Score    Votes   Gross         Director              Cast1  \
# 1      9.3   80.0  2407245   28.34   Frank Darabont        Tim Robbins
# 2      8.1   83.0   645186   16.50      Danny Boyle      Ewan McGregor
# ...

# %%
drm_s = d[(d["Genre"]=="Drama") & (d["Date"] > 1900)]
drm_s.head()
# Out:
#      Ranking  IMDByear           IMDBlink                            Title  \
# 1          2      1996  /title/tt0111161/         The Shawshank Redemption
# 2          3      1996  /title/tt0117951/                    Trainspotting
# 19        20      1996  /title/tt0073486/  One Flew Over the Cuckoo's Nest
# 152      153      1996  /title/tt0056801/                               8½
# 174      175      1996  /title/tt0042192/                    All About Eve
#
#      Date  RunTime  Genre  Rating  Score    Votes   Gross  \
# 1    1994      142  Drama     9.3   80.0  2407245   28.34
# 2    1996       93  Drama     8.1   83.0   645186   16.50
# 19   1975      133  Drama     8.7   84.0   936416  112.00
# 152  1963      138  Drama     8.0   91.0   111159    0.05
# 174  1950      138  Drama     8.2   98.0   122994    0.01
#
#                  Director                  Cast1              Cast2  \
# 1          Frank Darabont            Tim Robbins     Morgan Freeman
# ...

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x="Date",y="Rating", data=drm_s)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Rating'>

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x="Date",y="Rating", data=drm_s, hue= "Rating")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Rating'>

# %%
drm_s.head()
# Out:
#      Ranking  IMDByear           IMDBlink                            Title  \
# 1          2      1996  /title/tt0111161/         The Shawshank Redemption
# 2          3      1996  /title/tt0117951/                    Trainspotting
# 19        20      1996  /title/tt0073486/  One Flew Over the Cuckoo's Nest
# 152      153      1996  /title/tt0056801/                               8½
# 174      175      1996  /title/tt0042192/                    All About Eve
#
#      Date  RunTime  Genre  Rating  Score    Votes   Gross  \
# 1    1994      142  Drama     9.3   80.0  2407245   28.34
# 2    1996       93  Drama     8.1   83.0   645186   16.50
# 19   1975      133  Drama     8.7   84.0   936416  112.00
# 152  1963      138  Drama     8.0   91.0   111159    0.05
# 174  1950      138  Drama     8.2   98.0   122994    0.01
#
#                  Director                  Cast1              Cast2  \
# 1          Frank Darabont            Tim Robbins     Morgan Freeman
# ...

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date", y="Rating", data=d)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Rating'>

# %%
drm_s.dtypes
# Out:
# Ranking       int64
# IMDByear      int64
# IMDBlink     object
# Title        object
# Date          int64
# RunTime       int64
# Genre        object
# Rating      float64
# Score       float64
# Votes         int64
# Gross       float64
# Director     object
# Cast1        object
# Cast2        object
# Cast3        object
# Cast4        object
# dtype: object

# %%
data_2010 = d[(d["Date"] > 2010)]
data_2010.head()
# Out:
#       Ranking  IMDByear           IMDBlink                    Title  Date  \
# 3857      108      2011  /title/tt1832382/  Jodaeiye Nader az Simin  2011
# 4104      105      2012  /title/tt1832382/  Jodaeiye Nader az Simin  2011
# 4350      101      2013  /title/tt1832382/  Jodaeiye Nader az Simin  2011
# 4381      132      2013  /title/tt2106476/                   Jagten  2012
# 4498      249      2013  /title/tt1454029/                 The Help  2011
#
#       RunTime  Genre  Rating  Score   Votes   Gross           Director  \
# 3857      123  Drama     8.3   95.0  226052    7.10     Asghar Farhadi
# 4104      123  Drama     8.3   95.0  226052    7.10     Asghar Farhadi
# 4350      123  Drama     8.3   95.0  226052    7.10     Asghar Farhadi
# 4381      115  Drama     8.3   77.0  294379    0.69  Thomas Vinterberg
# 4498      146  Drama     8.0   62.0  434956  169.71        Tate Taylor
#
#                 Cast1               Cast2                Cast3  \
# ...

# %%
plt.figure(figsize=(15,5))
for movie in d["Genre"].unique():
    data = d[d["Genre"]== movie]
    sns.lineplot(x="Date", y="Rating", data=data)
plt.legend(d["Genre"].unique())

# %%
plt.figure(figsize=(15,5))
da.plot()
# Out:
# <AxesSubplot:>

# %%
da["Rating"].plot()
# Out:
# <AxesSubplot:>

# %%
da.plot.scatter(x= "Score", y= "Rating", alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Rating'>

# %%
[
    method_name
    for method_name in dir(da.plot)
    if not method_name.startswith("_")
    
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
axs = da.plot.area(figsize=(12,4), subplots= True)

# %%
fig, axs = plt.subplots(figsize= (12,4))
da.plot.area(ax=axs)
axs.set_ylabel("NO$_2$ concentration")
fig.savefig("no2_concentration.png")
